# %%
# !pip install 'numpy>=1.16,<1.25'
# !pip install 'pandas>=1.0.1'
# !pip install 'torch>=1.9.0'
# !pip install 'pymoo==0.6.0'
# !pip install 'scikit-learn>=0.22'
# !pip install 'gpytorch>=1.4.0'
# !pip install 'GPy>=1.9.9'
# !pip install 'catboost>=0.24.4'
# !pip install disjoint-set
# Out:
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1) (1.17.0)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9.0) (3.0.3)
# Requirement already satisfied: pymoo==0.6.0 in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (1.26.4)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (1.12.0)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (3.10.0)
# Requirement already satisfied: autograd>=1.4 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (1.8.0)
# Requirement already satisfied: cma==3.2.2 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (3.2.2)
# Requirement already satisfied: alive-progress in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (3.3.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (0.3.8)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.12/dist-packages (from pymoo==0.6.0) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.6.0) (2.9.0.post0)
# Requirement already satisfied: about-time==4.2.1 in /usr/local/lib/python3.12/dist-packages (from alive-progress->pymoo==0.6.0) (4.2.1)
# Requirement already satisfied: graphemeu==0.7.2 in /usr/local/lib/python3.12/dist-packages (from alive-progress->pymoo==0.6.0) (0.7.2)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from Deprecated->pymoo==0.6.0) (2.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo==0.6.0) (1.17.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22) (3.6.0)
# Requirement already satisfied: gpytorch>=1.4.0 in /usr/local/lib/python3.12/dist-packages (1.14.3)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.4.0) (0.3.3)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.4.0) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.4.0) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.4.0) (1.12.0)
# Requirement already satisfied: linear_operator>=0.6 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.4.0) (0.6)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from linear_operator>=0.6->gpytorch>=1.4.0) (2.9.0+cu126)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from scipy>=1.6.0->gpytorch>=1.4.0) (1.26.4)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping->gpytorch>=1.4.0) (0.1.7)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->gpytorch>=1.4.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->gpytorch>=1.4.0) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->linear_operator>=0.6->gpytorch>=1.4.0) (3.0.3)
# Requirement already satisfied: GPy>=1.9.9 in /usr/local/lib/python3.12/dist-packages (1.13.2)
# Requirement already satisfied: numpy<2.0.0,>=1.7 in /usr/local/lib/python3.12/dist-packages (from GPy>=1.9.9) (1.26.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from GPy>=1.9.9) (1.17.0)
# Requirement already satisfied: paramz>=0.9.6 in /usr/local/lib/python3.12/dist-packages (from GPy>=1.9.9) (0.9.6)
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.12/dist-packages (from GPy>=1.9.9) (3.0.12)
# Requirement already satisfied: scipy<=1.12.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from GPy>=1.9.9) (1.12.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.12/dist-packages (from paramz>=0.9.6->GPy>=1.9.9) (4.4.2)
# Requirement already satisfied: catboost>=0.24.4 in /usr/local/lib/python3.12/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (1.12.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost>=0.24.4) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost>=0.24.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost>=0.24.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost>=0.24.4) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost>=0.24.4) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost>=0.24.4) (9.1.2)
# Requirement already satisfied: disjoint-set in /usr/local/lib/python3.12/dist-packages (0.8.0)

# %%
# !pip install HEBO --no-deps
# Out:
# Requirement already satisfied: HEBO in /usr/local/lib/python3.12/dist-packages (0.3.6)

# %% [markdown]
# # Example with a 2D synthetic function
#
# Let's consider a simple example in 2-dimension so we can visualize everything.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from hebo.optimizers.hebo import HEBO
from hebo.optimizers.bo import BO

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Objective Function
#
# We define below an objective function `obj` that takes as inputs a dataframe object `pandas.DataFrame`, i.e. a table, with two columns named `"x0","x1"`.

# %%
a = 1.0
b = 5.1 / (4 * np.pi**2)
c = 5 / np.pi
d = 6.0
e = 10.0
f = 1 / (8 * np.pi)

def branin_hoo(x : pd.DataFrame) -> np.ndarray:
    """Calculates the Branin-Hoo function value."""
    x = x[['x0','x1']].values
    x0, x1 = x[:,0], x[:,1]
    term1 = a * (x1 - b * x0**2 + c * x0 - d)**2
    term2 = e * (1 - f) * np.cos(x0)
    term3 = e
    return np.array(term1 + term2 + term3).reshape(-1, 1)

# %% [markdown]
# ### Design  Space
#
# To be able to use `HEBO` and in general for using any numerical optimizer, we need to specify the design space, i.e. the space in which the inputs to the objective live in and a bounding box in which we will search for the optimal input $x^*=\arg\min f(x)$ that minimizes the objective $f(\cdot)$.

# %%
from hebo.design_space.design_space import DesignSpace
space = DesignSpace().parse([
    {'name' : 'x0', 'type' : 'num', 'lb' : -5, 'ub' : 10},
    {'name' : 'x1', 'type' : 'num', 'lb' : 0,  'ub' : 15}
])

# %%
from scipy.interpolate import griddata

# 1. Generate Scattered Data Points
X_df = space.sample(200)
Y_flat = branin_hoo(X_df).ravel()

points = X_df[['x0', 'x1']].values
values = Y_flat

# --- 2. Define the Target Grid for Interpolation ---
n_points = 150  # Define resolution for the heatmap (150x150 grid)
x0_arr = np.linspace(space.opt_lb[0], space.opt_ub[0], n_points)
x1_arr = np.linspace(space.opt_lb[1], space.opt_ub[1], n_points)
X0_grid, X1_grid = np.meshgrid(x0_arr, x1_arr)

# --- 3. Interpolate the Scattered Data onto the Grid ---
Z_grid = griddata(points, values, (X0_grid, X1_grid), method='cubic')

# --- 4. Create the Heatmap/Contour Plot ---
plt.figure(figsize=(8, 6))
cont = plt.contourf(X0_grid, X1_grid, Z_grid, levels=40, cmap='viridis')
plt.contour(X0_grid, X1_grid, Z_grid, levels=10, colors='k', linestyles='-', linewidths=0.5, alpha=0.5)
plt.colorbar(cont, label="Interpolated Objective Value")
plt.xlabel("x0")
plt.ylabel("x1")
plt.title("Heatmap of Branin-Hoo Function (Interpolated from 200 Samples)")
plt.grid(True, linestyle='--', alpha=0.3)
plt.show()

# %% [markdown]
# ### BO Loop
#
# We compare three BO algorithms:
# - The basic BO with LCB acquisition
# - HEBO where three acquisition functions are ensembled, with input warping and power transformation
# - HEBO with parallel recommendation.
#
# We'll run BO with LCB firstly, we can see the interface is very simple

# %%
NUM_ITERATIONS = 64

# %%
bo = BO(space)
for i in range(NUM_ITERATIONS):
    rec_x = bo.suggest(n_suggestions=1)
    bo.observe(rec_x, branin_hoo(rec_x))
    if i % 4 == 0:
        print('Iter %d, best_y = %.2f' % (i, bo.y.min()))
# Out:
# Iter 0, best_y = 17.51
# Iter 4, best_y = 8.30
# Iter 8, best_y = 1.04
# Iter 12, best_y = 0.42
# Iter 16, best_y = 0.42
# Iter 20, best_y = 0.42
# Iter 24, best_y = 0.42
# Iter 28, best_y = 0.42
# Iter 32, best_y = 0.42
# Iter 36, best_y = 0.42
# Iter 40, best_y = 0.42
# Iter 44, best_y = 0.42
# Iter 48, best_y = 0.41
# Iter 52, best_y = 0.41
# Iter 56, best_y = 0.40
# Iter 60, best_y = 0.40

# %% [markdown]
# We then run the sequential HEBO

# %%
hebo_seq   = HEBO(space, model_name = 'gp', rand_sample = 4)
for i in range(NUM_ITERATIONS):
    rec_x = hebo_seq.suggest(n_suggestions=1)
    hebo_seq.observe(rec_x, branin_hoo(rec_x))
    if i % 4 == 0:
        print('Iter %d, best_y = %.2f' % (i, hebo_seq.y.min()))
# Out:
# Iter 0, best_y = 131.10
# Iter 4, best_y = 17.34
# Iter 8, best_y = 1.93
# Iter 12, best_y = 0.51
# Iter 16, best_y = 0.43
# Iter 20, best_y = 0.40
# Iter 24, best_y = 0.40
# Iter 28, best_y = 0.40
# Iter 32, best_y = 0.40
# Iter 36, best_y = 0.40
# Iter 40, best_y = 0.40
# Iter 44, best_y = 0.40
# Iter 48, best_y = 0.40
# Iter 52, best_y = 0.40
# Iter 56, best_y = 0.40
# Iter 60, best_y = 0.40

# %% [markdown]
# Finally, we run the parallel HEBO, as it would do parallel recommendation, we only run it for 16 iterations

# %%
hebo_batch = HEBO(space, model_name = 'gp', rand_sample = 4)
for i in range(NUM_ITERATIONS // 8):
    rec_x = hebo_batch.suggest(n_suggestions=8)
    hebo_batch.observe(rec_x, branin_hoo(rec_x))
    print('Iter %d, best_y = %.2f' % (i, hebo_batch.y.min()))
# Out:
# Iter 0, best_y = 2.85
# Iter 1, best_y = 2.79
# Iter 2, best_y = 0.56
# Iter 3, best_y = 0.42
# Iter 4, best_y = 0.41
# Iter 5, best_y = 0.40
# Iter 6, best_y = 0.40
# Iter 7, best_y = 0.40

# %% [markdown]
# We plot the converge below, we can see it seems that the LCB converges slightly faster than HEBO, while batched HEBO used most function evaluations.

# %%
conv_hebo_batch = np.minimum.accumulate(hebo_batch.y)
conv_hebo_seq = np.minimum.accumulate(hebo_seq.y)
conv_bo_seq = np.minimum.accumulate(bo.y)

plt.figure(figsize = (8,6))
plt.semilogy(conv_hebo_batch - 0.3978922, '.-', label = 'HEBO, Parallel,Batch = 8')
plt.semilogy(conv_hebo_seq - 0.3978922, '.-', label = 'HEBO, Sequential')
plt.semilogy(conv_bo_seq - 0.3978922, '.-', label = 'BO, LCB')

plt.xlabel('Evaluation')
plt.ylabel('Regret')
plt.legend()

# %% [markdown]
# Batched HEBO used most function evaluations because it recommend eight points per iterations, we can also plot the converge against **iterations** instead of **evaluations**.

# %%
plt.figure(figsize = (8,6))
plt.semilogy(conv_hebo_batch[::8] - 0.3978922, '.-', label = 'HEBO, Parallel,Batch = 8')
plt.semilogy(conv_hebo_seq - 0.3978922, '.-', label = 'HEBO, Sequential')
plt.semilogy(conv_bo_seq - 0.3978922, '.-', label = 'BO, LCB')

plt.xlabel('Iterations')
plt.ylabel('Regret')
plt.legend()

# %% [markdown]
# # Example on a real dataset
#
# For that part, load the `HER_virtual_data.csv` dataset from your laptop to the notebook.
#
# Now, because HEBO is by default *minimizing* functions, we just need to take the negative of the `Target` column as objective values if we want to maximize the target.
#
# So we flip the target values to be `max(targets) - targets` so that they are all nonegative and finding the smallest one is equivalent to finding the largest original target value.

# %%
data = pd.read_csv('HER_virtual_data.csv')
true_best_y = data["Target"].max()
data["Target"] = data["Target"].max() - data["Target"]

# %%
params = [
    {'name' : 'AcidRed871_0gL',     'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'L-Cysteine-50gL',    'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'MethyleneB_250mgL',  'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'NaCl-3M',            'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'NaOH-1M',            'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'P10-MIX1',           'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'PVP-1wt',            'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'RhodamineB1_0gL',    'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'SDS-1wt',            'type' : 'num', 'lb' : 0, 'ub' : 5},
    {'name' : 'Sodiumsilicate-1wt', 'type' : 'num', 'lb' : 0, 'ub' : 5},
]

space = DesignSpace().parse(params)

# %%
NUM_ITERATIONS = 250
NUM_SUGGESTIONS_PER_ITERATION = 1

# %% [markdown]
# ### Optimization with a dynamic Oracle
#
# Because in this case we do not have a real objective function definition, i.e. an *oracle*, we are going to use the dataset directly to show how BO works. We randomly split the data into an observation set and a test set, making sure the best point is in the test set.
#
# In particular, we make sure that the best 10% points are not in the training set.

# %%
from sklearn.model_selection import train_test_split

num_best_to_exclude = max(1, int(0.10 * len(data)))
data_best = data.sort_values(by='Target').head(num_best_to_exclude)
indices_to_drop = data_best.index

data_rest = data.drop(indices_to_drop)
data_train, data_test_partial = train_test_split(data_rest, test_size=0.9, random_state=42)
data_test = pd.concat([data_test_partial, data_best])

X_train = data_train[space.numeric_names]
Y_train = data_train["Target"].values.reshape(-1, 1)
X_test = data_test[space.numeric_names]
Y_test = data_test["Target"].values.reshape(-1, 1)

print("#Train data", data_train.shape[0])
print("#Test data", data_test.shape[0])
# Out:
# #Train data 73
# #Test data 739

# %% [markdown]
# We define a function to find the closest point to the `HEBO` suggestion in the `X_test` dataframe and we take the corresponding value from `Y_test` as objective value.

# %%
from scipy.spatial.distance import cdist # Required for efficient distance calculation

def find_nearest_row(df: pd.DataFrame, vector: np.ndarray, feature_cols: list = None) -> int:
    """
    Finds the row in the DataFrame that is closest to the input vector
    using Euclidean distance.
    """
    if not feature_cols:
        feature_cols = df.columns.tolist()

    # 1. Extract feature data from the DataFrame
    df_features = df[feature_cols].values

    # 2. Calculate the distance between the vector and all rows
    # cdist is highly efficient for this calculation
    distances = cdist(df_features, vector.reshape(1, -1), metric='euclidean')

    # 3. Find the index of the minimum distance
    nearest_idx_in_df = np.argmin(distances)

    # 4. Return the full row from the original DataFrame
    return nearest_idx_in_df

# %%
hebo = HEBO(space, model_name='gp')
hebo.observe(X_train, Y_train) # observe X_train and Y_train
for i in range(NUM_ITERATIONS):
    rec_x = hebo.suggest(n_suggestions=NUM_SUGGESTIONS_PER_ITERATION) # HEBO suggests a new point
    idx = find_nearest_row(X_test, rec_x.values) # find closest point for which we have the true value in X_test
    rec_y = Y_test[idx]
    hebo.observe(rec_x, rec_y)
    if i % 4 == 0:
        print(f'Iter {i}, best_y = {hebo.y.min():.5f}, y_opt = {Y_test.min():.5f} '
              f'(true best_y = {-(hebo.y.min()-true_best_y):.5f}, true y_opt = {true_best_y:.5f})')
# Out:
# Iter 0, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 4, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 8, best_y = 10.85658, y_opt = 0.00000 (true best_y = 16.84752, true y_opt = 27.70410)
# Iter 12, best_y = 8.71147, y_opt = 0.00000 (true best_y = 18.99264, true y_opt = 27.70410)
# Iter 16, best_y = 8.71147, y_opt = 0.00000 (true best_y = 18.99264, true y_opt = 27.70410)
# Iter 20, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 24, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 28, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 32, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 36, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 40, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 44, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 48, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 52, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 56, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 60, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 64, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 68, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 72, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 76, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 80, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 84, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 88, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 92, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 96, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 100, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 104, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 108, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 112, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 116, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 120, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 124, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 128, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 132, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 136, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 140, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 144, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 148, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 152, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 156, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 160, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 164, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 168, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 172, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 176, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 180, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 184, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 188, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 192, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 196, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 200, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 204, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 208, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 212, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 216, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 220, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 224, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 228, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 232, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 236, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 240, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 244, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 248, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)

# %%
bo = BO(space, model_name='gp')
bo.observe(X_train, Y_train) # observe X_train and Y_train
for i in range(NUM_ITERATIONS):
    rec_x = bo.suggest(n_suggestions=NUM_SUGGESTIONS_PER_ITERATION) # BO suggests a new point
    idx = find_nearest_row(X_test, rec_x.values) # find closest point for which we have the true value in X_test
    rec_y = Y_test[idx]
    bo.observe(rec_x, rec_y.reshape(-1, 1))
    if i % 4 == 0:
        print(f'Iter {i}, best_y = {bo.y.min():.5f}, y_opt = {Y_test.min():.5f} '
              f'(true best_y = {-(bo.y.min()-true_best_y):.5f}, true y_opt = {true_best_y:.5f})')
# Out:
# Iter 0, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 4, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 8, best_y = 10.85658, y_opt = 0.00000 (true best_y = 16.84752, true y_opt = 27.70410)
# Iter 12, best_y = 10.85658, y_opt = 0.00000 (true best_y = 16.84752, true y_opt = 27.70410)
# Iter 16, best_y = 10.85658, y_opt = 0.00000 (true best_y = 16.84752, true y_opt = 27.70410)
# Iter 20, best_y = 10.69026, y_opt = 0.00000 (true best_y = 17.01385, true y_opt = 27.70410)
# Iter 24, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 28, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 32, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 36, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 40, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 44, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 48, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 52, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 56, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 60, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 64, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 68, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 72, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 76, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 80, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 84, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 88, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 92, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 96, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 100, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 104, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 108, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 112, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 116, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 120, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 124, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 128, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 132, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 136, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 140, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 144, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 148, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 152, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 156, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 160, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 164, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 168, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 172, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 176, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 180, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 184, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 188, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 192, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 196, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 200, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 204, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 208, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 212, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 216, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 220, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 224, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 228, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 232, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 236, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 240, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 244, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)
# Iter 248, best_y = 8.41906, y_opt = 0.00000 (true best_y = 19.28505, true y_opt = 27.70410)

# %%
rs_log = Y_train.flatten()
for i in range(NUM_ITERATIONS):
    rec_x = space.sample(NUM_SUGGESTIONS_PER_ITERATION) # sample a new point from the search space
    idx = find_nearest_row(X_test, rec_x.values) # find closest point for which we have the true value in X_test
    rec_y = Y_test[idx]
    rs_log = np.concatenate([rs_log, rec_y])
    if i % 4 == 0:
        print(f'Iter {i}, best_y = {rs_log.min():.5f}, y_opt = {Y_test.min():.5f} '
              f'(true best_y = {-(rs_log.min()-true_best_y):.5f}, true y_opt = {true_best_y:.5f})')
# Out:
# Iter 0, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 4, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 8, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 12, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 16, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 20, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 24, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 28, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 32, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 36, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 40, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 44, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 48, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 52, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 56, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 60, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 64, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 68, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 72, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 76, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 80, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 84, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 88, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 92, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 96, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 100, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 104, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 108, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 112, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 116, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 120, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 124, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 128, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 132, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 136, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 140, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 144, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 148, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 152, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 156, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 160, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 164, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 168, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 172, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 176, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 180, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 184, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 188, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 192, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 196, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 200, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 204, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 208, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 212, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 216, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 220, best_y = 11.36265, y_opt = 0.00000 (true best_y = 16.34146, true y_opt = 27.70410)
# Iter 224, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)
# Iter 228, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)
# Iter 232, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)
# Iter 236, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)
# Iter 240, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)
# Iter 244, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)
# Iter 248, best_y = 10.68018, y_opt = 0.00000 (true best_y = 17.02393, true y_opt = 27.70410)

# %% [markdown]
# Note that we plot the *Regret* i.e. how close we are getting to the best value in the test set.

# %%
conv_hebo = np.minimum.accumulate(hebo.y)
conv_bo = np.minimum.accumulate(bo.y)
conv_rs = np.minimum.accumulate(rs_log)

plt.figure(figsize = (8,6))
plt.semilogy(conv_hebo[len(X_train):], '.-', label = 'HEBO')
plt.semilogy(conv_bo[len(X_train):], '.-', label = 'BO')
plt.semilogy(conv_rs[len(X_train):], '.-', label = 'RS')
plt.xlabel('Evaluation')
plt.ylabel('Regret')
plt.legend()
plt.grid()
plt.title("Optimization of Photocatalytic Water Splitting with 'Nearest-Neighbour' Orcale")
plt.show()

# %% [markdown]
# ### Optimization with a learnt Orcale
#
# In this example, we are going to *learn* an oracle function.
#
# In the previous example we were finding the point in the test dataset closest to the new suggested point by the BO algoritm and using its real `Target` value. This has the benefit of using the *true* value associated with the ppoint, but the drawback is that we are not really observing the point that the BO algorithm suggested.
#
# In this following example we make the opposite tradeoff: we learn an oracle, i.e. we learn a model of the `Target` values with a regression model, and we use this *learnt oracle* as our optimization objective. The advantage of this method is that we can now use this oracle to evaluate any point suggested by the BO algorithm. The drawback is that the values are not the *true* values but only *predicted*.
#
# Both examples are methods that are used in practice, the user needs to be aware fo the drawbacks and advantages of both methods but they are both valid ways of comparing optimization algorithms. In the ideal case of course we would like to evaluate the true `Target` value of each new suggested point, but in practice this is not possible because of the prohibitive costs of such evaluations (e.g. requiring wet lab experiments).

# %%
from typing import Callable

def construct_oracle(
    data_path: str,
    impl: str = "random_forest"
) -> Callable[[pd.DataFrame], np.ndarray]:

    data = pd.read_csv(data_path)
    target = data["Target"]
    features = data.drop(columns=["Target"])

    # learn a decision tree model as oracle
    if impl == "random_forest":
        from sklearn.ensemble import RandomForestRegressor
        model = RandomForestRegressor(n_estimators=100)
        model.fit(features, target)

        return lambda x: model.predict(x)
    else:
        raise ValueError(f"Unsupported implementation: {impl}")

# %%
oracle = construct_oracle(data_path="HER_virtual_data.csv")

# %%
hebo = HEBO(space, model_name='gp')
hebo.observe(X_train, Y_train) # observe X_train and Y_train
for i in range(NUM_ITERATIONS):
    rec_x = hebo.suggest(n_suggestions=NUM_SUGGESTIONS_PER_ITERATION) # HEBO suggests a new point
    rec_y = oracle(rec_x)
    hebo.observe(rec_x, rec_y)
    if i % 4 == 0:
        print(f'Iter {i}, best_y = {hebo.y.min():.5f}, y_opt = {Y_test.min():.5f} '
              f'(true best_y = {-(hebo.y.min()-true_best_y):.5f}, true y_opt = {true_best_y:.5f})')
# Out:
# Iter 0, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 4, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 8, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 12, best_y = 10.21161, y_opt = 0.00000 (true best_y = 17.49250, true y_opt = 27.70410)
# Iter 16, best_y = 9.88056, y_opt = 0.00000 (true best_y = 17.82355, true y_opt = 27.70410)
# Iter 20, best_y = 9.88056, y_opt = 0.00000 (true best_y = 17.82355, true y_opt = 27.70410)
# Iter 24, best_y = 9.88056, y_opt = 0.00000 (true best_y = 17.82355, true y_opt = 27.70410)
# Iter 28, best_y = 9.79387, y_opt = 0.00000 (true best_y = 17.91023, true y_opt = 27.70410)
# Iter 32, best_y = 9.67979, y_opt = 0.00000 (true best_y = 18.02431, true y_opt = 27.70410)
# Iter 36, best_y = 5.21971, y_opt = 0.00000 (true best_y = 22.48440, true y_opt = 27.70410)
# Iter 40, best_y = 5.21971, y_opt = 0.00000 (true best_y = 22.48440, true y_opt = 27.70410)
# Iter 44, best_y = 4.85913, y_opt = 0.00000 (true best_y = 22.84497, true y_opt = 27.70410)
# Iter 48, best_y = 4.85913, y_opt = 0.00000 (true best_y = 22.84497, true y_opt = 27.70410)
# Iter 52, best_y = 4.85913, y_opt = 0.00000 (true best_y = 22.84497, true y_opt = 27.70410)
# Iter 56, best_y = 4.11036, y_opt = 0.00000 (true best_y = 23.59374, true y_opt = 27.70410)
# Iter 60, best_y = 4.11036, y_opt = 0.00000 (true best_y = 23.59374, true y_opt = 27.70410)
# Iter 64, best_y = 3.93557, y_opt = 0.00000 (true best_y = 23.76854, true y_opt = 27.70410)
# Iter 68, best_y = 2.77087, y_opt = 0.00000 (true best_y = 24.93323, true y_opt = 27.70410)
# Iter 72, best_y = 2.77087, y_opt = 0.00000 (true best_y = 24.93323, true y_opt = 27.70410)
# Iter 76, best_y = 2.62677, y_opt = 0.00000 (true best_y = 25.07734, true y_opt = 27.70410)
# Iter 80, best_y = 2.62677, y_opt = 0.00000 (true best_y = 25.07734, true y_opt = 27.70410)
# Iter 84, best_y = 1.64488, y_opt = 0.00000 (true best_y = 26.05923, true y_opt = 27.70410)
# Iter 88, best_y = 1.64488, y_opt = 0.00000 (true best_y = 26.05923, true y_opt = 27.70410)
# Iter 92, best_y = 1.51174, y_opt = 0.00000 (true best_y = 26.19237, true y_opt = 27.70410)
# Iter 96, best_y = 1.51174, y_opt = 0.00000 (true best_y = 26.19237, true y_opt = 27.70410)
# Iter 100, best_y = 1.47675, y_opt = 0.00000 (true best_y = 26.22735, true y_opt = 27.70410)
# Iter 104, best_y = 1.37317, y_opt = 0.00000 (true best_y = 26.33093, true y_opt = 27.70410)
# Iter 108, best_y = 1.32310, y_opt = 0.00000 (true best_y = 26.38100, true y_opt = 27.70410)
# Iter 112, best_y = 1.23447, y_opt = 0.00000 (true best_y = 26.46963, true y_opt = 27.70410)
# Iter 116, best_y = 1.02922, y_opt = 0.00000 (true best_y = 26.67488, true y_opt = 27.70410)
# Iter 120, best_y = 1.02922, y_opt = 0.00000 (true best_y = 26.67488, true y_opt = 27.70410)
# Iter 124, best_y = 0.82416, y_opt = 0.00000 (true best_y = 26.87995, true y_opt = 27.70410)
# Iter 128, best_y = 0.69842, y_opt = 0.00000 (true best_y = 27.00569, true y_opt = 27.70410)
# Iter 132, best_y = 0.68257, y_opt = 0.00000 (true best_y = 27.02153, true y_opt = 27.70410)
# Iter 136, best_y = 0.68257, y_opt = 0.00000 (true best_y = 27.02153, true y_opt = 27.70410)
# Iter 140, best_y = 0.68257, y_opt = 0.00000 (true best_y = 27.02153, true y_opt = 27.70410)
# Iter 144, best_y = 0.68257, y_opt = 0.00000 (true best_y = 27.02153, true y_opt = 27.70410)
# Iter 148, best_y = 0.67060, y_opt = 0.00000 (true best_y = 27.03351, true y_opt = 27.70410)
# Iter 152, best_y = 0.63440, y_opt = 0.00000 (true best_y = 27.06971, true y_opt = 27.70410)
# Iter 156, best_y = 0.61488, y_opt = 0.00000 (true best_y = 27.08922, true y_opt = 27.70410)
# Iter 160, best_y = 0.20532, y_opt = 0.00000 (true best_y = 27.49878, true y_opt = 27.70410)
# Iter 164, best_y = 0.19004, y_opt = 0.00000 (true best_y = 27.51407, true y_opt = 27.70410)
# Iter 168, best_y = 0.19004, y_opt = 0.00000 (true best_y = 27.51407, true y_opt = 27.70410)
# Iter 172, best_y = 0.19004, y_opt = 0.00000 (true best_y = 27.51407, true y_opt = 27.70410)
# Iter 176, best_y = 0.19004, y_opt = 0.00000 (true best_y = 27.51407, true y_opt = 27.70410)
# Iter 180, best_y = 0.18292, y_opt = 0.00000 (true best_y = 27.52118, true y_opt = 27.70410)
# Iter 184, best_y = 0.18292, y_opt = 0.00000 (true best_y = 27.52118, true y_opt = 27.70410)
# Iter 188, best_y = 0.18292, y_opt = 0.00000 (true best_y = 27.52118, true y_opt = 27.70410)
# Iter 192, best_y = 0.18292, y_opt = 0.00000 (true best_y = 27.52118, true y_opt = 27.70410)
# Iter 196, best_y = 0.18292, y_opt = 0.00000 (true best_y = 27.52118, true y_opt = 27.70410)
# Iter 200, best_y = 0.17857, y_opt = 0.00000 (true best_y = 27.52554, true y_opt = 27.70410)
# Iter 204, best_y = 0.17857, y_opt = 0.00000 (true best_y = 27.52554, true y_opt = 27.70410)
# Iter 208, best_y = 0.17857, y_opt = 0.00000 (true best_y = 27.52554, true y_opt = 27.70410)
# Iter 212, best_y = 0.17857, y_opt = 0.00000 (true best_y = 27.52554, true y_opt = 27.70410)
# Iter 216, best_y = 0.17694, y_opt = 0.00000 (true best_y = 27.52716, true y_opt = 27.70410)
# Iter 220, best_y = 0.17694, y_opt = 0.00000 (true best_y = 27.52716, true y_opt = 27.70410)
# Iter 224, best_y = 0.17624, y_opt = 0.00000 (true best_y = 27.52786, true y_opt = 27.70410)
# Iter 228, best_y = 0.17486, y_opt = 0.00000 (true best_y = 27.52925, true y_opt = 27.70410)
# Iter 232, best_y = 0.17486, y_opt = 0.00000 (true best_y = 27.52925, true y_opt = 27.70410)
# Iter 236, best_y = 0.17486, y_opt = 0.00000 (true best_y = 27.52925, true y_opt = 27.70410)
# Iter 240, best_y = 0.17486, y_opt = 0.00000 (true best_y = 27.52925, true y_opt = 27.70410)
# Iter 244, best_y = 0.17486, y_opt = 0.00000 (true best_y = 27.52925, true y_opt = 27.70410)
# Iter 248, best_y = 0.17486, y_opt = 0.00000 (true best_y = 27.52925, true y_opt = 27.70410)

# %%
bo = BO(space, model_name='gp')
bo.observe(X_train, Y_train) # observe X_train and Y_train
for i in range(NUM_ITERATIONS):
    rec_x = bo.suggest(n_suggestions=NUM_SUGGESTIONS_PER_ITERATION) # BO suggests a new point
    rec_y = oracle(rec_x)
    bo.observe(rec_x, rec_y.reshape(-1, 1))
    if i % 4 == 0:
        print(f'Iter {i}, best_y = {bo.y.min():.5f}, y_opt = {Y_test.min():.5f} '
              f'(true best_y = {-(bo.y.min()-true_best_y):.5f}, true y_opt = {true_best_y:.5f})')
# Out:
# Iter 0, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 4, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 8, best_y = 12.03105, y_opt = 0.00000 (true best_y = 15.67306, true y_opt = 27.70410)
# Iter 12, best_y = 11.83365, y_opt = 0.00000 (true best_y = 15.87045, true y_opt = 27.70410)
# Iter 16, best_y = 11.49145, y_opt = 0.00000 (true best_y = 16.21265, true y_opt = 27.70410)
# Iter 20, best_y = 11.31482, y_opt = 0.00000 (true best_y = 16.38928, true y_opt = 27.70410)
# Iter 24, best_y = 8.93759, y_opt = 0.00000 (true best_y = 18.76652, true y_opt = 27.70410)
# Iter 28, best_y = 8.93759, y_opt = 0.00000 (true best_y = 18.76652, true y_opt = 27.70410)
# Iter 32, best_y = 8.60655, y_opt = 0.00000 (true best_y = 19.09756, true y_opt = 27.70410)
# Iter 36, best_y = 8.37332, y_opt = 0.00000 (true best_y = 19.33078, true y_opt = 27.70410)
# Iter 40, best_y = 7.94730, y_opt = 0.00000 (true best_y = 19.75680, true y_opt = 27.70410)
# Iter 44, best_y = 7.82152, y_opt = 0.00000 (true best_y = 19.88259, true y_opt = 27.70410)
# Iter 48, best_y = 7.82152, y_opt = 0.00000 (true best_y = 19.88259, true y_opt = 27.70410)
# Iter 52, best_y = 7.82152, y_opt = 0.00000 (true best_y = 19.88259, true y_opt = 27.70410)
# Iter 56, best_y = 7.82152, y_opt = 0.00000 (true best_y = 19.88259, true y_opt = 27.70410)
# Iter 60, best_y = 7.82152, y_opt = 0.00000 (true best_y = 19.88259, true y_opt = 27.70410)
# Iter 64, best_y = 7.57860, y_opt = 0.00000 (true best_y = 20.12550, true y_opt = 27.70410)
# Iter 68, best_y = 7.57860, y_opt = 0.00000 (true best_y = 20.12550, true y_opt = 27.70410)
# Iter 72, best_y = 7.52863, y_opt = 0.00000 (true best_y = 20.17547, true y_opt = 27.70410)
# Iter 76, best_y = 7.41744, y_opt = 0.00000 (true best_y = 20.28666, true y_opt = 27.70410)
# Iter 80, best_y = 7.36475, y_opt = 0.00000 (true best_y = 20.33935, true y_opt = 27.70410)
# Iter 84, best_y = 7.27180, y_opt = 0.00000 (true best_y = 20.43231, true y_opt = 27.70410)
# Iter 88, best_y = 7.27180, y_opt = 0.00000 (true best_y = 20.43231, true y_opt = 27.70410)
# Iter 92, best_y = 7.27180, y_opt = 0.00000 (true best_y = 20.43231, true y_opt = 27.70410)
# Iter 96, best_y = 7.27180, y_opt = 0.00000 (true best_y = 20.43231, true y_opt = 27.70410)
# Iter 100, best_y = 7.26110, y_opt = 0.00000 (true best_y = 20.44301, true y_opt = 27.70410)
# Iter 104, best_y = 7.21460, y_opt = 0.00000 (true best_y = 20.48951, true y_opt = 27.70410)
# Iter 108, best_y = 7.14737, y_opt = 0.00000 (true best_y = 20.55673, true y_opt = 27.70410)
# Iter 112, best_y = 7.14737, y_opt = 0.00000 (true best_y = 20.55673, true y_opt = 27.70410)
# Iter 116, best_y = 7.14737, y_opt = 0.00000 (true best_y = 20.55673, true y_opt = 27.70410)
# Iter 120, best_y = 7.14737, y_opt = 0.00000 (true best_y = 20.55673, true y_opt = 27.70410)
# Iter 124, best_y = 7.14737, y_opt = 0.00000 (true best_y = 20.55673, true y_opt = 27.70410)
# Iter 128, best_y = 7.12534, y_opt = 0.00000 (true best_y = 20.57877, true y_opt = 27.70410)
# Iter 132, best_y = 7.12534, y_opt = 0.00000 (true best_y = 20.57877, true y_opt = 27.70410)
# Iter 136, best_y = 7.12534, y_opt = 0.00000 (true best_y = 20.57877, true y_opt = 27.70410)
# Iter 140, best_y = 7.12534, y_opt = 0.00000 (true best_y = 20.57877, true y_opt = 27.70410)
# Iter 144, best_y = 7.12534, y_opt = 0.00000 (true best_y = 20.57877, true y_opt = 27.70410)
# Iter 148, best_y = 7.12534, y_opt = 0.00000 (true best_y = 20.57877, true y_opt = 27.70410)
# Iter 152, best_y = 7.09425, y_opt = 0.00000 (true best_y = 20.60986, true y_opt = 27.70410)
# Iter 156, best_y = 7.09425, y_opt = 0.00000 (true best_y = 20.60986, true y_opt = 27.70410)
# Iter 160, best_y = 7.09425, y_opt = 0.00000 (true best_y = 20.60986, true y_opt = 27.70410)
# Iter 164, best_y = 7.09425, y_opt = 0.00000 (true best_y = 20.60986, true y_opt = 27.70410)
# Iter 168, best_y = 7.09425, y_opt = 0.00000 (true best_y = 20.60986, true y_opt = 27.70410)
# Iter 172, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 176, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 180, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 184, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 188, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 192, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 196, best_y = 7.05686, y_opt = 0.00000 (true best_y = 20.64725, true y_opt = 27.70410)
# Iter 200, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 204, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 208, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 212, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 216, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 220, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 224, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 228, best_y = 6.92355, y_opt = 0.00000 (true best_y = 20.78056, true y_opt = 27.70410)
# Iter 232, best_y = 6.87872, y_opt = 0.00000 (true best_y = 20.82538, true y_opt = 27.70410)
# Iter 236, best_y = 6.87872, y_opt = 0.00000 (true best_y = 20.82538, true y_opt = 27.70410)
# Iter 240, best_y = 6.87872, y_opt = 0.00000 (true best_y = 20.82538, true y_opt = 27.70410)
# Iter 244, best_y = 6.77703, y_opt = 0.00000 (true best_y = 20.92707, true y_opt = 27.70410)
# Iter 248, best_y = 6.77703, y_opt = 0.00000 (true best_y = 20.92707, true y_opt = 27.70410)

# %%
rs_log = Y_train.flatten()
for i in range(NUM_ITERATIONS):
    rec_x = space.sample(NUM_SUGGESTIONS_PER_ITERATION) # sample a new point from the search space
    rec_y = oracle(rec_x)
    rs_log = np.concatenate([rs_log, rec_y])
    if i % 4 == 0:
        print(f'Iter {i}, best_y = {rs_log.min():.5f}, y_opt = {Y_test.min():.5f} '
              f'(true best_y = {-(rs_log.min()-true_best_y):.5f}, true y_opt = {true_best_y:.5f})')

# %%
conv_hebo = np.minimum.accumulate(hebo.y)
conv_bo = np.minimum.accumulate(bo.y)
conv_rs = np.minimum.accumulate(rs_log)

plt.figure(figsize = (8,6))
plt.semilogy(conv_hebo[len(X_train):], '.-', label = 'HEBO')
plt.semilogy(conv_bo[len(X_train):], '.-', label = 'BO')
plt.semilogy(conv_rs[len(X_train):], '.-', label = 'RS')
plt.xlabel('Evaluation')
plt.ylabel('Regret')
plt.legend()
plt.grid()
plt.title("Optimization of Photocatalytic Water Splitting - with Learnt Orcale")

plt.show()
